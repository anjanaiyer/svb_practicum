# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('buyouts_funds_final.csv')

# %%
df.head()
# Out:
#    fund_id                         fund_name  fm_id  \
# 0    34866       Ascent Venture Partners VII   6381
# 1    43446            Volunteer Park Capital  19143
# 2    44723       Flashstarts Blockchain Fund  14468
# 3    44727               Harmony Partners IV  10317
# 4    44738  Light Street Beacon Principals I  19412
#
#                           strategy       sector         region        country  \
# 0  Venture Capital / Growth Equity          TMT  North America  United States
# 1                 Mezzanine / Debt  Diversified  North America            NaN
# 2  Venture Capital / Growth Equity          TMT  North America  United States
# 3  Venture Capital / Growth Equity          TMT  North America  United States
# 4  Venture Capital / Growth Equity          TMT  North America  United States
#
#    target_fund_size_amt target_fund_size_currency  fund_size_amt  \
# 0           150000000.0                       USD            NaN
# ...

# %%
df2 = pd.read_csv('/Users/AmeliaMazer/Documents/2022_svb_github/buyouts/buyouts_lp/buyouts_lp_csv/lp_commitments.csv')

# %%
df2.head()
# Out:
#    lp_commitment_id  lp_id  fund_id                      fund_name  \
# 0            215027      3    60421  Greenspring Global Partners V
# 1            195565      3    60421  Greenspring Global Partners V
# 2            181373      3    60421  Greenspring Global Partners V
# 3            125752      3    60421  Greenspring Global Partners V
# 4             88550      3    60421  Greenspring Global Partners V
#
#    fund_manager_id     fund_manager     sectors  \
# 0             7045  StepStone Group  Healthcare
# 1             7045  StepStone Group         TMT
# 2             7045  StepStone Group  Healthcare
# 3             7045  StepStone Group         TMT
# 4             7045  StepStone Group  Healthcare
#
#                       strategies  fund_size_amt fund_size_currency  \
# 0  Fund of Funds / Co-Investment    356190000.0                USD
# 1  Fund of Funds / Co-Investment    356190000.0                USD
# ...

# %%
 df_outer = df.merge(df2,how='outer')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_outer.head()
# Out:
#    fund_id                         fund_name    fm_id  \
# 0    34866       Ascent Venture Partners VII   6381.0
# 1    43446            Volunteer Park Capital  19143.0
# 2    44723       Flashstarts Blockchain Fund  14468.0
# 3    44727               Harmony Partners IV  10317.0
# 4    44738  Light Street Beacon Principals I  19412.0
#
#                           strategy       sector         region        country  \
# 0  Venture Capital / Growth Equity          TMT  North America  United States
# 1                 Mezzanine / Debt  Diversified  North America            NaN
# 2  Venture Capital / Growth Equity          TMT  North America  United States
# 3  Venture Capital / Growth Equity          TMT  North America  United States
# 4  Venture Capital / Growth Equity          TMT  North America  United States
#
#    target_fund_size_amt target_fund_size_currency  fund_size_amt  \
# 0           150000000.0                       USD            NaN
# ...

# %%
from sklearn import cluster

# %%
df_outer.drop(columns =['fund_id','fund_name','status','stage','vintage_year','open_date',\
                              'lp_commitment_id', 'lp_id','fund_manager'], axis = 1)
