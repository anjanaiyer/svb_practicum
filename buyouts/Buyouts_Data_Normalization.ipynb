# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import numpy as np
import regex as re

# %%
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('buyouts_funds/buyouts_funds_csv/buyouts_funds_orig.csv')
df.head()
# Out:
#       ID                                      Name  \
# 0  34866               Ascent Venture Partners VII
# 1  36284     Fall Line Endurance Fund (Open-Ended)
# 2  39769  Star Mountain U.S. LMM Secondary Fund II
# 3  42607              Lumerity Capital Partners II
# 4  43372                 Waterfall Sentinel Fund I
#
#                   FundManager  FundManagerID  \
# 0     Ascent Venture Partners           6381
# 1           Fall Line Capital          15168
# 2       Star Mountain Capital           1671
# 3            Lumerity Capital          18403
# 4  Waterfall Asset Management          19136
#
#                             Strategy         Region              Sector  \
# 0    Venture Capital / Growth Equity  North America                 TMT
# 1    Venture Capital / Growth Equity  North America  TMT / Agribusiness
# 2                        Secondaries  North America         Diversified
# 3  Buyout / Corporate Private Equity  North America                 TMT
# ...

# %%
df.shape
# Out:
# (3066, 12)

# %%
df = df.set_index(['ID', 'Name', 'FundManager', 'FundManagerID','Region', 'Sector', 'VintageYear','YearOpened', 'MonthsOpened', 'TargetSize' ,'Currency'])\
    .stack()\
   .str.split('/', expand=True)\
    .stack()\
    .unstack(-2)\
   .reset_index(-1, drop=True)\
   .reset_index()

# %%
df.head()
# Out:
#       ID                                      Name              FundManager  \
# 0  34866               Ascent Venture Partners VII  Ascent Venture Partners
# 1  34866               Ascent Venture Partners VII  Ascent Venture Partners
# 2  36284     Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
# 3  36284     Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
# 4  39769  Star Mountain U.S. LMM Secondary Fund II    Star Mountain Capital
#
#    FundManagerID         Region              Sector  VintageYear  YearOpened  \
# 0           6381  North America                 TMT         2020        2020
# 1           6381  North America                 TMT         2020        2020
# 2          15168  North America  TMT / Agribusiness         2019        2016
# 3          15168  North America  TMT / Agribusiness         2019        2016
# 4           1671  North America         Diversified         2020        2020
#
# ...

# %%
df = df.set_index(['ID', 'Name', 'FundManager', 'FundManagerID','Strategy', 'Sector', 'VintageYear','YearOpened', 'MonthsOpened', 'TargetSize' ,'Currency'])\
    .stack()\
   .str.split('/', expand=True)\
    .stack()\
    .unstack(-2)\
   .reset_index(-1, drop=True)\
   .reset_index()

# %%
df.tail()
# Out:
#          ID                            Name  FundManager  FundManagerID  \
# 9021  61847         ARC Group Ventures fund    ARC Group          23014
# 9022  61847         ARC Group Ventures fund    ARC Group          23014
# 9023  61847         ARC Group Ventures fund    ARC Group          23014
# 9024  61849  NFX Capital Opportunity Fund I  NFX Capital          18781
# 9025  61849  NFX Capital Opportunity Fund I  NFX Capital          18781
#
#               Strategy Sector  VintageYear  YearOpened  MonthsOpened  \
# 9021  Venture Capital     TMT         2022        2022             4
# 9022  Venture Capital     TMT         2022        2022             4
# 9023  Venture Capital     TMT         2022        2022             4
# 9024     Growth Equity    TMT         2021        2021             0
# 9025  Venture Capital     TMT         2021        2021             0
#
#        TargetSize Currency           Region
# 9021   20000000.0      USD    Asia-Pacific
# ...

# %%
df = df.set_index(['ID', 'Name', 'FundManager', 'FundManagerID','Strategy', 'Region', 'VintageYear','YearOpened', 'MonthsOpened', 'TargetSize' ,'Currency'])\
    .stack()\
   .str.split('/', expand=True)\
    .stack()\
    .unstack(-2)\
   .reset_index(-1, drop=True)\
   .reset_index()

# %%
df.head()
# Out:
#       ID                                   Name              FundManager  \
# 0  34866            Ascent Venture Partners VII  Ascent Venture Partners
# 1  34866            Ascent Venture Partners VII  Ascent Venture Partners
# 2  36284  Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
# 3  36284  Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
# 4  36284  Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
#
#    FundManagerID          Strategy         Region  VintageYear  YearOpened  \
# 0           6381     Growth Equity  North America         2020        2020
# 1           6381  Venture Capital   North America         2020        2020
# 2          15168     Growth Equity  North America         2019        2016
# 3          15168     Growth Equity  North America         2019        2016
# 4          15168  Venture Capital   North America         2019        2016
#
#    MonthsOpened   TargetSize Currency         Sector
# ...

# %%
df.columns =[
   'fund_id',
    'fund_name',
    'fund_manager',
    'fund_manager_id',
    'strategy',
    'region',
    'vintage_year',
    'year_opened',
    'month_launched',
    'target_size',
    'currency',
    'sector'
]

# %%
list_col =  df.columns.to_list()
df = df.reindex(columns= list_col)

# %%
df.head()
# Out:
#    fund_id                              fund_name             fund_manager  \
# 0    34866            Ascent Venture Partners VII  Ascent Venture Partners
# 1    34866            Ascent Venture Partners VII  Ascent Venture Partners
# 2    36284  Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
# 3    36284  Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
# 4    36284  Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
#
#    fund_manager_id          strategy         region  vintage_year  \
# 0             6381     Growth Equity  North America          2020
# 1             6381  Venture Capital   North America          2020
# 2            15168     Growth Equity  North America          2019
# 3            15168     Growth Equity  North America          2019
# 4            15168  Venture Capital   North America          2019
#
#    year_opened  month_launched  target_size currency         sector
# ...

# %%
#df.to_csv('funds_1NF.csv', index = False)

# %%
df2 = df.copy()

# %%
df2.drop('fund_manager_id', axis = 1, inplace = True)

# %%
df2.head()
# Out:
#    fund_id                              fund_name             fund_manager  \
# 0    34866            Ascent Venture Partners VII  Ascent Venture Partners
# 1    34866            Ascent Venture Partners VII  Ascent Venture Partners
# 2    36284  Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
# 3    36284  Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
# 4    36284  Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
#
#            strategy         region  vintage_year  year_opened  month_launched  \
# 0     Growth Equity  North America          2020         2020               0
# 1  Venture Capital   North America          2020         2020               0
# 2     Growth Equity  North America          2019         2016               7
# 3     Growth Equity  North America          2019         2016               7
# 4  Venture Capital   North America          2019         2016               7
#
#    target_size currency         sector
# ...

# %%
df2['month_launched']=df2['month_launched'].apply(str)

# %%
df2['year_opened']=df2['year_opened'].apply(str)

# %%
df2['open_date'] = df2['year_opened']+ '-' + df2['month_launched']

# %%
df2.head()
# Out:
#    fund_id                              fund_name             fund_manager  \
# 0    34866            Ascent Venture Partners VII  Ascent Venture Partners
# 1    34866            Ascent Venture Partners VII  Ascent Venture Partners
# 2    36284  Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
# 3    36284  Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
# 4    36284  Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
#
#            strategy         region  vintage_year year_opened month_launched  \
# 0     Growth Equity  North America          2020        2020              0
# 1  Venture Capital   North America          2020        2020              0
# 2     Growth Equity  North America          2019        2016              7
# 3     Growth Equity  North America          2019        2016              7
# 4  Venture Capital   North America          2019        2016              7
#
#    target_size currency         sector open_date
# ...

# %%
df2.drop(columns =['month_launched','year_opened'], axis = 1, inplace = True)

# %%
df2.head()
# Out:
#    fund_id                              fund_name             fund_manager  \
# 0    34866            Ascent Venture Partners VII  Ascent Venture Partners
# 1    34866            Ascent Venture Partners VII  Ascent Venture Partners
# 2    36284  Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
# 3    36284  Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
# 4    36284  Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
#
#            strategy         region  vintage_year  target_size currency  \
# 0     Growth Equity  North America          2020  150000000.0      USD
# 1  Venture Capital   North America          2020  150000000.0      USD
# 2     Growth Equity  North America          2019          NaN      NaN
# 3     Growth Equity  North America          2019          NaN      NaN
# 4  Venture Capital   North America          2019          NaN      NaN
#
#           sector open_date
# 0            TMT    2020-0
# 1            TMT    2020-0
# ...

# %%
list_col = df2.columns.tolist()

# %%
list_col.insert(df2.columns.get_loc('vintage_year') ,list_col.pop(-1))

# %%
df2 = df2.reindex(columns= list_col)

# %%
df2.head()
# Out:
#    fund_id                              fund_name             fund_manager  \
# 0    34866            Ascent Venture Partners VII  Ascent Venture Partners
# 1    34866            Ascent Venture Partners VII  Ascent Venture Partners
# 2    36284  Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
# 3    36284  Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
# 4    36284  Fall Line Endurance Fund (Open-Ended)        Fall Line Capital
#
#            strategy         region open_date  vintage_year  target_size  \
# 0     Growth Equity  North America    2020-0          2020  150000000.0
# 1  Venture Capital   North America    2020-0          2020  150000000.0
# 2     Growth Equity  North America    2016-7          2019          NaN
# 3     Growth Equity  North America    2016-7          2019          NaN
# 4  Venture Capital   North America    2016-7          2019          NaN
#
#   currency         sector
# 0      USD            TMT
# 1      USD            TMT
# ...

# %%
#df2.to_csv('funds_3NF.csv', index = False)

# %%
df2.to_csv('buyouts_funds/buyouts_funds_csv/byo_funds.csv',index = False)

# %%
df1 = pd.read_csv('buyouts_lp/buyouts_lp_csv/buyouts_lp_orig.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0  ID                         Name                       Type  \
# 0          74   3             Abell Foundation     Foundation / Endowment
# 1          22   4                     ABN AMRO  Bank / Financial Services
# 2        3294   5  Stichting Pensioenfonds ABP        Public Pension Fund
# 3          28   8                    AEGON USA          Insurance Company
# 4         105   9                        Aetna       Private Pension Fund
#
#    TypeID                        HQ   AssetAmount Currency
# 0       5  Baltimore, United States  3.586300e+08      USD
# 1      25    Amsterdam, Netherlands  4.199500e+11      EUR
# 2      12      Heerlen, Netherlands  5.500000e+11      EUR
# 3       8  Baltimore, United States           NaN      NaN
# 4      26   Hartford, United States  5.710000e+09      USD

# %%
df1.drop('Unnamed: 0', axis=1, inplace = True)

# %%
df1.shape
# Out:
# (4146, 7)

# %%
df1.head()
# Out:
#    ID                         Name                       Type  TypeID  \
# 0   3             Abell Foundation     Foundation / Endowment       5
# 1   4                     ABN AMRO  Bank / Financial Services      25
# 2   5  Stichting Pensioenfonds ABP        Public Pension Fund      12
# 3   8                    AEGON USA          Insurance Company       8
# 4   9                        Aetna       Private Pension Fund      26
#
#                          HQ   AssetAmount Currency
# 0  Baltimore, United States  3.586300e+08      USD
# 1    Amsterdam, Netherlands  4.199500e+11      EUR
# 2      Heerlen, Netherlands  5.500000e+11      EUR
# 3  Baltimore, United States           NaN      NaN
# 4   Hartford, United States  5.710000e+09      USD

# %%
df1['HQ'].replace('\.','', regex=True, inplace = True)

# %%
df1['HQ'].replace('\, DC', ' DC', regex=True, inplace = True)

# %%
df1.head()
# Out:
#    ID                         Name                       Type  TypeID  \
# 0   3             Abell Foundation     Foundation / Endowment       5
# 1   4                     ABN AMRO  Bank / Financial Services      25
# 2   5  Stichting Pensioenfonds ABP        Public Pension Fund      12
# 3   8                    AEGON USA          Insurance Company       8
# 4   9                        Aetna       Private Pension Fund      26
#
#                          HQ   AssetAmount Currency
# 0  Baltimore, United States  3.586300e+08      USD
# 1    Amsterdam, Netherlands  4.199500e+11      EUR
# 2      Heerlen, Netherlands  5.500000e+11      EUR
# 3  Baltimore, United States           NaN      NaN
# 4   Hartford, United States  5.710000e+09      USD

# %%
df1.tail()
# Out:
#          ID                                 Name                  Type  \
# 4141  22849                   Whitehelm Advisers       Investment Firm
# 4142  22850                      Cerity Partners       Investment Firm
# 4143  22873  Offit Capital Investment Consultant       Investment Firm
# 4144  22878         Arch Street Capital Advisors       Investment Firm
# 4145  22977            Unum Group's Pension Fund  Private Pension Fund
#
#       TypeID                          HQ   AssetAmount Currency
# 4141       9         Canberra, Australia           NaN      NaN
# 4142       9     New York, United States           NaN      NaN
# 4143       9     New York, United States           NaN      NaN
# 4144       9     New York, United States           NaN      NaN
# 4145      26  Chattanooga, United States  1.800000e+09      USD

# %%
df1.Type.unique()
# Out:
# array(['Foundation / Endowment', 'Bank / Financial Services',
#        'Public Pension Fund', 'Insurance Company', 'Private Pension Fund',
#        'Government Related Investment Organisation', 'Asset Manager',
#        'Family Office', 'Corporate', 'Fund of Funds Manager',
#        'Investment Firm', 'Sovereign Wealth Fund', 'Independent Firm',
#        'Gatekeepers', 'Bank Subsidiary/Division',
#        'Corporate Subsidiary/Division'], dtype=object)

# %%
df1.groupby('HQ')['HQ'].count()
# Out:
# HQ
# Aarau, Switzerland                          1
# Abbott Park, United States                  1
# Aberdeen, United Kingdom                    1
# Abidjan, Côte d`Ivoire                      1
# Abilene, United States                      2
# Abu Dhabi, United Arab Emirates            10
# Abuja, Nigeria                              1
# Ada, United States                          1
# Adelaide, Australia                         2
# Adelphi, United States                      1
# Adliswil, Switzerland                       1
# Agawam, United States                       1
# Aker Brygge, Norway                         1
# Akron, United States                        2
# Akureyri, Iceland                           1
# Al Khobar, Saudi Arabia                     1
# Albany, United States                       3
# Albuquerque, United States                  5
# Alexandria, United States                   3
# Alfred, United States                       1
# ...

# %%
df1[['hq_city', 'hq_country']] = df1['HQ'].str.split(',',1, expand = True)

# %%
df1.tail()
# Out:
#          ID                                 Name                  Type  \
# 4141  22849                   Whitehelm Advisers       Investment Firm
# 4142  22850                      Cerity Partners       Investment Firm
# 4143  22873  Offit Capital Investment Consultant       Investment Firm
# 4144  22878         Arch Street Capital Advisors       Investment Firm
# 4145  22977            Unum Group's Pension Fund  Private Pension Fund
#
#       TypeID                          HQ   AssetAmount Currency      hq_city  \
# 4141       9         Canberra, Australia           NaN      NaN     Canberra
# 4142       9     New York, United States           NaN      NaN     New York
# 4143       9     New York, United States           NaN      NaN     New York
# 4144       9     New York, United States           NaN      NaN     New York
# 4145      26  Chattanooga, United States  1.800000e+09      USD  Chattanooga
#
#           hq_country
# 4141       Australia
# 4142   United States
# ...

# %%
df1.drop('HQ', axis = 1, inplace = True)

# %%
df1.head()
# Out:
#    ID                         Name                       Type  TypeID  \
# 0   3             Abell Foundation     Foundation / Endowment       5
# 1   4                     ABN AMRO  Bank / Financial Services      25
# 2   5  Stichting Pensioenfonds ABP        Public Pension Fund      12
# 3   8                    AEGON USA          Insurance Company       8
# 4   9                        Aetna       Private Pension Fund      26
#
#     AssetAmount Currency    hq_city      hq_country
# 0  3.586300e+08      USD  Baltimore   United States
# 1  4.199500e+11      EUR  Amsterdam     Netherlands
# 2  5.500000e+11      EUR    Heerlen     Netherlands
# 3           NaN      NaN  Baltimore   United States
# 4  5.710000e+09      USD   Hartford   United States

# %%
df1.columns =[
    'lp_id',
    'lp_name',
    'type',
    'type_id',
    'asset_amount',
    'currency',
    'hq_city',
    'hq_country'
]

# %%
list_col1 = df1.columns.tolist()

# %%
df1.head()
# Out:
#    lp_id                      lp_name                       type  type_id  \
# 0      3             Abell Foundation     Foundation / Endowment        5
# 1      4                     ABN AMRO  Bank / Financial Services       25
# 2      5  Stichting Pensioenfonds ABP        Public Pension Fund       12
# 3      8                    AEGON USA          Insurance Company        8
# 4      9                        Aetna       Private Pension Fund       26
#
#    asset_amount currency    hq_city      hq_country
# 0  3.586300e+08      USD  Baltimore   United States
# 1  4.199500e+11      EUR  Amsterdam     Netherlands
# 2  5.500000e+11      EUR    Heerlen     Netherlands
# 3           NaN      NaN  Baltimore   United States
# 4  5.710000e+09      USD   Hartford   United States

# %%
df1.to_csv('buyouts_lp/buyouts_lp_csv/lp_1NF.csv', index = False)

# %%
df3 = df1.copy()

# %%
df3.shape
# Out:
# (4146, 8)

# %%
types = df3.filter(['type_id', 'type'], axis=1)

# %%
types.head()
# Out:
#    type_id                       type
# 0        5     Foundation / Endowment
# 1       25  Bank / Financial Services
# 2       12        Public Pension Fund
# 3        8          Insurance Company
# 4       26       Private Pension Fund

# %%
types = types.sort_values("type_id")

# %%
types = types.drop_duplicates(subset ="type_id", keep = "first")

# %%
types.to_csv('buyouts_lp/buyouts_lp_csv/lp_types.csv')

# %%
types.head()
# Out:
#       type_id                    type
# 681         1           Asset Manager
# 3783        3               Corporate
# 2472        4           Family Office
# 1914        5  Foundation / Endowment
# 2313        8       Insurance Company

# %%
lp_types = df3.filter(['lp_id', 'type_id'], axis=1)

# %%
lp_types
# Out:
#       lp_id  type_id
# 0         3        5
# 1         4       25
# 2         5       12
# 3         8        8
# 4         9       26
# 5        10        8
# 6        14       12
# 7        15       12
# 8        16       23
# 9        18       26
# 10       19        5
# 11       20        5
# 12       23       12
# 13       24        5
# 14       25        8
# 15       26        5
# 16       27        5
# 17       28        5
# 18       30        1
# 19       31        5
# 20       32       12
# 21       33       12
# 22       34       12
# 23       35       12
# 24       37       12
# 25       38       12
# 26       40       12
# 27       41       12
# 28       42       26
# 29       45        8
# 30       48        4
# 31       50       25
# 32       54       26
# 33       55        3
# 34       59        5
# 35       60        1
# 36       62       26
# 37       64        4
# 38       65        5
# 39       66        5
# 40       67       26
# 41       68        1
# ...

# %%
lp_types = lp_types.sort_values('lp_id')

# %%
lp_types = lp_types.drop_duplicates(subset ="lp_id", keep = "first")

# %%
lp_types.to_csv('buyouts_lp/buyouts_lp_csv/lp_typ_associative.csv')

# %%
lp_types
# Out:
#       lp_id  type_id
# 0         3        5
# 1         4       25
# 2         5       12
# 3         8        8
# 4         9       26
# 5        10        8
# 6        14       12
# 7        15       12
# 8        16       23
# 9        18       26
# 10       19        5
# 11       20        5
# 12       23       12
# 13       24        5
# 14       25        8
# 15       26        5
# 16       27        5
# 17       28        5
# 18       30        1
# 19       31        5
# 20       32       12
# 21       33       12
# 22       34       12
# 23       35       12
# 24       37       12
# 25       38       12
# 26       40       12
# 27       41       12
# 28       42       26
# 29       45        8
# 30       48        4
# 31       50       25
# 32       54       26
# 33       55        3
# 34       59        5
# 35       60        1
# 36       62       26
# 37       64        4
# 38       65        5
# 39       66        5
# 40       67       26
# 41       68        1
# ...
