# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('investor_info.csv')

# %%
df.head()
# Out:
#    investor_id                          investor_name investment_num  \
# 0            1             Spruce Investment Advisors            NaN
# 1            2                                   CAIS            NaN
# 2            3  South Africa Alpha Capital Management            NaN
# 3            4                         Alpha Partners             21
# 4            5                          TEXO Ventures             19
#
#    total_funds_open  total_funds_closed     AUM dry_powder  \
# 0              14.0                 6.0  182.40        NaN
# 1              13.0                 3.0  176.40     474.22
# 2              11.0                 NaN  114.90     256.29
# 3              10.0                 2.0  145.70      92.77
# 4               9.0                 1.0   15.41       0.77
#
#   last_investment_type last_investment_valuation last_investment_size  ...  \
# 0                  NaN                       NaN                  NaN  ...
# ...

# %%
df1 = pd.read_csv('investor_lp.csv')

# %%
df1.head()
# Out:
#    investment_id                 investor_name  \
# 0              1                          CAIS
# 1              2                Alpha Partners
# 2              3  Emerald Development Managers
# 3              4  Emerald Development Managers
# 4              5  Emerald Development Managers
#
#                         limited_partnter_name  commitments
# 0                McWane Salaried Pension Plan          1.0
# 1                           RosePaul Ventures          NaN
# 2  New York City Employees' Retirement System          1.0
# 3  New York City Fire Department Pension Fund          1.0
# 4           New York City Police Pension Fund          1.0

# %%
df1.drop(columns =['Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', \
                   'Unnamed: 10', 'Unnamed: 11','Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',\
                  'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',\
                  'Unnamed: 24', 'Unnamed: 25'],  axis=1, inplace = True)

# %%
df1.to_csv('investor_lp.csv')

# %%
df2 = pd.read_csv('lp_info.csv')

# %%
df2.head()
# Out:
#    lp_id                                        lp_name  cmmt_in_vc_funds  \
# 0      1                                   lmpactAssets              22.0
# 1      2  John D. and Catherine T. MacArthur Foundation              17.0
# 2      3                       Illinois State Treasurer              21.0
# 3      4          New York State Common Retirement Fund              10.0
# 4      5                       European Investment Fund              17.0
#
#    total_cmmt_in_vc_funds limited_partner_type         AUM  \
# 0                    43.0           Foundation    2,000.00
# 1                   123.0           Foundation    8,000.77
# 2                    49.0    Government Agency   52,000.00
# 3                   178.0  Public Pension Fund  280,000.00
# 4                   542.0        Fund of Funds    3,019.79
#
#    affliated_funds_num  affliated_investors_num  commitments total_cmmt  \
# 0                 28.0                     22.0         28.0         68
# ...

# %%
df2.drop(columns =['Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',\
                  'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19'],  axis=1, inplace = True)

# %%
df2.tail()
# Out:
#       lp_id                                            lp_name  \
# 1966   1967                                              Zcube
# 1967   1968  Zhejiang Daily Digital Culture Group (SHG: 600...
# 1968   1969             Zhejiang Provincial Financial Holdings
# 1969   1970                               Ziff Davis (NAS: ZD)
# 1970   1971                                       Zema Capital
#
#       cmmt_in_vc_funds  total_cmmt_in_vc_funds         limited_partner_type  \
# 1966               1.0                     1.0                  Corporation
# 1967               1.0                     2.0                  Corporation
# 1968               1.0                     8.0  Economic Development Agency
# 1969               1.0                     1.0                  Corporation
# 1970               1.0                     3.0        Family Office (Multi)
#
#           AUM  affliated_funds_num  affliated_investors_num  commitments  \
# ...

# %%
df2['hq_location'] = df2['hq_location'].astype('str')

# %%
df2.hq_location.replace('\?', ' ', regex=True, inplace )
# Out:
# 0                 Bethesda, MD
# 1                  Chicago, IL
# 2              Springfield, IL
# 3                   Albany, NY
# 4       Luxembourg, Luxembourg
#                  ...
# 1966              Milan, Italy
# 1967           Hangzhou, China
# 1968           Hangzhou, China
# 1969              New York, NY
# 1970                Denver, CO
# Name: hq_location, Length: 1971, dtype: object

# %%
df2.hq_location.dtypes
# Out:
# dtype('O')
